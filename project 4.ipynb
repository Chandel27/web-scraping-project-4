# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\brijesh\anaconda3\lib\site-packages (4.4.3)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\brijesh\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\brijesh\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\brijesh\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\brijesh\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\brijesh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\brijesh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\brijesh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\brijesh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sniffio in c:\users\brijesh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\brijesh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\brijesh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\brijesh\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\brijesh\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\brijesh\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\brijesh\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time
import requests

# %%
# import debugger
import pdb

import re
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.alert import Alert

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
# get webelements for all 30 rows
top30_rows_wbe=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']//following::tbody")
# get webelement for table with top 30 YT videos list
# store all text in a list
for i in top30_rows_wbe:
    temp_text=i.text
    break # exit after first iteration
    
sep_rows=temp_text.split('\n')

rank=[]
rank.clear()
vid_name=[]
vid_name.clear()
artist=[]
artist.clear()
views=[]
views.clear()
date=[]
date.clear()

for i in sep_rows:
    
    rank.append(i.split('.')[0])
    
    vid_name.append(i.split('[')[0].split('.')[-1].strip())
    
    artist.append(re.split('\d+',i.split(']')[1])[0])
    
    views.append(str(re.compile('\d+').findall(i.split(']')[1])[0])+'.'+str(re.compile('\d+').findall(i.split(']')[1])[1]))
    
    date.append(str(re.compile('[a-zA-Z]+\s+\d{2}').findall(i.split('.')[2]))+','+str(re.compile('\d{4}').findall(i.split('.')[2])))

# %%
top30_vid=pd.DataFrame({})
top30_vid['Rank']=rank
top30_vid['Name']=vid_name
top30_vid['Artist']=artist
top30_vid['Views (in billions)']=views
top30_vid['Release Date']=date

# %%
top30_vid
# Out:
#    Rank                                         Name  \
# 0     1                           "Baby Shark Dance"
# 1     2                                  "Despacito"
# 2     3                       "Johny Johny Yes Papa"
# 3     4                               "Shape of You"
# 4     5                              "See You Again"
# 5     6                                  "Bath Song"
# 6     7                "Phonics Song with Two Words"
# 7     8                                "Uptown Funk"
# 8     9  "Learning Colors – Colorful Eggs on a Farm"
# 9    10                              "Gangnam Style"
# 10   11   "Masha and the Bear – Recipe for Disaster"
# 11   12                          "Wheels on the Bus"
# 12   13                             "Dame Tu Cosita"
# 13   14                                      "Sugar"
# 14   15                                       "Roar"
# 15   16                             "Counting Stars"
# 16   17                                      "Sorry"
# 17   18                                     "Axel F"
# 18   18                          "Thinking Out Loud"
# 19   20                        "Baa Baa Black Sheep"
# 20   21                                 "Dark Horse"
# 21   22                                      "Faded"
# 22   23                             "Girls Like You"
# 23   24                                 "Let Her Go"
# 24   25                                   "Bailando"
# 25   26                                    "Lean On"
# 26   27                                    "Perfect"
# 27   28           "Waka Waka (This Time for Africa)"
# 28   29                               "Shake It Off"
# 29   30          "Humpty the train on a fruits ride"
#
#                                              Artist Views (in billions)  \
# 0      Pinkfong Baby Shark - Kids' Songs & Stories                11.24
# 1                                       Luis Fonsi                 7.96
# 2                                      LooLoo Kids                 6.44
# 3                                       Ed Sheeran                 5.80
# 4                                      Wiz Khalifa                 5.62
# 5                       Cocomelon – Nursery Rhymes                 5.59
# 6                                        ChuChu TV                 4.85
# 7                                      Mark Ronson                 4.68
# 8                                      Miroshka TV                 4.61
# 9                                              Psy                 4.53
# 10                                      Get Movies                 4.51
# 11                      Cocomelon – Nursery Rhymes                 4.31
# 12                                       El Chombo                 4.05
# 13                                          Maroon                  5.3
# 14                                      Katy Perry                 3.64
# 15                                     OneRepublic                 3.63
# 16                                   Justin Bieber                 3.58
# 17                                      Crazy Frog                 3.49
# 18                                      Ed Sheeran                 3.49
# 19                      Cocomelon – Nursery Rhymes                 3.35
# 20                                      Katy Perry                 3.34
# 21                                     Alan Walker                 3.33
# 22                                          Maroon                  5.3
# 23                                       Passenger                 3.29
# 24                                Enrique Iglesias                 3.26
# 25                                     Major Lazer                 3.25
# 26                                      Ed Sheeran                 3.24
# 27                                         Shakira                 3.23
# 28                                    Taylor Swift                 3.20
# 29   Kiddiestv Hindi – Nursery Rhymes & Kids Songs                 3.14
#
#                 Release Date
# 0       ['June 17'],['2016']
# 1    ['January 12'],['2017']
# 2                [],['2016']
# 3    ['January 30'],['2017']
# 4                [],['2015']
# 5                [],['2018']
# 6                [],['2014']
# 7   ['November 19'],['2014']
# 8   ['February 27'],['2018']
# 9       ['July 15'],['2012']
# 10   ['January 31'],['2012']
# 11       ['May 24'],['2018']
# 12               [],['2018']
# 13   ['January 14'],['2015']
# 14               [],['2013']
# 15       ['May 31'],['2013']
# 16   ['October 22'],['2015']
# 17      ['June 16'],['2009']
# 18               [],['2014']
# 19      ['June 25'],['2018']
# 20  ['February 20'],['2014']
# 21               [],['2015']
# 22       ['May 31'],['2018']
# 23      ['July 25'],['2012']
# 24     ['April 11'],['2014']
# 25     ['March 22'],['2015']
# 26               [],['2017']
# 27               [],['2010']
# 28    ['August 18'],['2014']
# 29   ['January 26'],['2018']

# %% [markdown]
# # Answer 2

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("http://www.bcci.tv/")

# %%
# click on "International" button to expand it
driver.find_element(By.XPATH,"//li[@class='nav-item']//a").click()

# click on 'Fixtures'
driver.find_element(By.XPATH,"//li[@data-nav-index='0']//following::a[@href='/international/fixtures']").click()

time.sleep(3)

# store webelements for all series names
series_wbe=driver.find_elements_by_xpath("//div[@class='fixture__format-strip']/span")

fixture_frame_text=[]

for i in series_wbe:
    fixture_frame_text.append(i.text)
    
fixture_name=[]
fixture_name.clear()
fixture_type=[]
fixture_type.clear()

time.sleep(3)

for i in range(len(fixture_frame_text)):
    if i%2!=0:
        fixture_name.append(fixture_frame_text[i])
    else:
        fixture_type.append(fixture_frame_text[i])

# get webelment for match title
title_wbe=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']")

title=[]
title.clear()
loc=[]
loc.clear()

for i in title_wbe:
    title.append(i.text.split('\n')[0])
    loc.append(i.text.split('\n')[1])
    
#get webelement for date and time
try:
    date_wbe=driver.find_elements_by_xpath("//div[@class='fixture__datetime desktop-only']")
except:
    pass

date=[]
date.clear()
time=[]
time.clear()

for i in date_wbe:
#     pdb.set_trace()
    date.append(str(i.text.split('\n')[0])+str('-')+str(i.text.split('\n')[1]+str('th')+str(i.text.split('\n')[2])))
    time.append(i.text.split('\n')[3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 5>()
#       2 driver.find_element(By.XPATH,"//li[@class='nav-item']//a").click()
#       4 # click on 'Fixtures'
# ----> 5 driver.find_element_by_xpath("//li[@data-nav-index='0']//following::a[@href='/international/fixtures']").click()
#       7 time.sleep(3)
#       9 # store webelements for all series names
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_xpath'

# %% [markdown]
# # Answer 3

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("http://www.guru99.com/")

# %%
# click on 'Selenium' on main page
#driver.find_element(By.XPATH,"//a[text()='Selenium']").click()
location=driver.find_element(By.XPATH,'//a[@class="gsc-input"]')
location.send_keys("selenium")                            
# time.sleep(5)
# click on Selenium Exception page
#driver.find_element_by_xpath("//td[contains(text(),'Selenium Exception')]//preceding-sibling::td[@class='responsivetable']").click()

# get webelement for table with data
#table_wbe=driver.find_element_by_xpath("//table[@class='table table-striped']")

#table_data = table_wbe.text

#row_data = table_data.split('\n')

#name=[]
#descr=[]

#for i in row_data[1:]:
#    name.append(i.split(' ')[0])
#    descr.append(' '.join(i.split(' ')[1:]))
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [28], in <cell line: 3>()
#       1 # click on 'Selenium' on main page
#       2 #driver.find_element(By.XPATH,"//a[text()='Selenium']").click()
# ----> 3 location=driver.find_element(By.XPATH,'//a[@class="gsc-input"]')
#       4 location.send_keys("selenium")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:855, in WebDriver.find_element(self, by, value)
#     852     by = By.CSS_SELECTOR
#     853     value = '[name="%s"]' % value
# --> 855 return self.execute(Command.FIND_ELEMENT, {
#     856     'using': by,
#     857     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//a[@class="gsc-input"]"}
#   (Session info: chrome=105.0.5195.102)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x007E78B3+2193587]
# 	Ordinal0 [0x00780681+1771137]
# 	Ordinal0 [0x006941A8+803240]
# 	Ordinal0 [0x006C24A0+992416]
# 	Ordinal0 [0x006C273B+993083]
# 	Ordinal0 [0x006EF7C2+1177538]
# 	Ordinal0 [0x006DD7F4+1103860]
# 	Ordinal0 [0x006EDAE2+1170146]
# 	Ordinal0 [0x006DD5C6+1103302]
# 	Ordinal0 [0x006B77E0+948192]
# 	Ordinal0 [0x006B86E6+952038]
# 	GetHandleVerifier [0x00A90CB2+2738370]
# 	GetHandleVerifier [0x00A821B8+2678216]
# 	GetHandleVerifier [0x008717AA+512954]
# 	GetHandleVerifier [0x00870856+509030]
# 	Ordinal0 [0x0078743B+1799227]
# 	Ordinal0 [0x0078BB68+1817448]
# 	Ordinal0 [0x0078BC55+1817685]
# 	Ordinal0 [0x00795230+1856048]
# 	BaseThreadInitThunk [0x76747BA9+25]
# 	RtlInitializeExceptionChain [0x7785BB3B+107]
# 	RtlClearBits [0x7785BABF+191]

# %%
guru99_tut=pd.DataFrame({})
guru99_tut['Exception']=name
guru99_tut['Description']=descr

# %%
guru99_tut.to_csv('selenium exceptions.csv')

# %%
pd.read_csv('selenium exceptions.csv')

# %% [markdown]
# # Answer 4

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("http://statisticstimes.com/")

# %%
search=driver.find_element(By.XPATH,'//button[@class="dropbtn"]')
search.click
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="961f59e813224011e9e9ea7ca176da66", element="0a065a94-ff7a-41b9-89ca-7393eabe6e9f")>>

# %%
eco_wbe = driver.find_element(By.XPATH,"//*[@id='top']/div[2]/div[2]/button")
# keep mouse on above webelement to get drop down list
#a.move_to_element(eco_wbe).perform()
#click on 'India' from drop down
driver.find_element(By.XPATH,"//a[@href='economy/india-statistics.php']").click() #//*[@id="top"]/div[2]/div[2]/div/a[3]

try:
    driver.find_element_by_xpath("//div[@id='ad_position_box']/div[@class='mys-wrapper']/div[@id='dismiss-button']").click()
except:
    time.sleep(4)
# click on Statwise GDP
driver.find_element_by_xpath("//div[contains(@style,'seashell')]/ul/li[1]").click()
#get webelements
rank_wbe = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr[@role='row']/td[1]")
state_wbe = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr[@role='row']/td[2]")
gsdp_19_wbe = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr[@role='row']/td[3]")
gsdp_18_wbe = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr[@role='row']/td[4]")
share_18_wbe = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr[@role='row']/td[5]")
gdp_wbe = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr[@role='row']/td[6]")
# get text from above webelements
rank=[]
state=[]
gsdp_19=[]
gsdp_18=[]
share_18=[]
gdp=[]
for i in rank_wbe:
    rank.append(i.text)
for i in state_wbe:
    state.append(i.text)
for i in gsdp_19_wbe:
    gsdp_19.append(i.text)
for i in gsdp_18_wbe:
    gsdp_18.append(i.text)
for i in share_18_wbe:
    share_18.append(i.text)
for i in gdp_wbe:
    gdp.append(i.text)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Input In [14], in <cell line: 5>()
#       1 eco_wbe = driver.find_element(By.XPATH,"//*[@id='top']/div[2]/div[2]/button")
#       2 # keep mouse on above webelement to get drop down list
#       3 #a.move_to_element(eco_wbe).perform()
#       4 #click on 'India' from drop down
# ----> 5 driver.find_element(By.XPATH,"//a[@href='economy/india-statistics.php']").click() #//*[@id="top"]/div[2]/div[2]/div/a[3]
#       7 try:
#       8     driver.find_element_by_xpath("//div[@id='ad_position_box']/div[@class='mys-wrapper']/div[@id='dismiss-button']").click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:88, in WebElement.click(self)
#      86 def click(self) -> None:
#      87     """Clicks the element."""
# ---> 88     self._execute(Command.CLICK_ELEMENT)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=105.0.5195.125)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x005378B3+2193587]
# 	Ordinal0 [0x004D0681+1771137]
# 	Ordinal0 [0x003E4070+802928]
# 	Ordinal0 [0x00413533+996659]
# 	Ordinal0 [0x00409223+954915]
# 	Ordinal0 [0x0042D7AC+1103788]
# 	Ordinal0 [0x00408C04+953348]
# 	Ordinal0 [0x0042D9C4+1104324]
# 	Ordinal0 [0x0043DAE2+1170146]
# 	Ordinal0 [0x0042D5C6+1103302]
# 	Ordinal0 [0x004077E0+948192]
# 	Ordinal0 [0x004086E6+952038]
# 	GetHandleVerifier [0x007E0CB2+2738370]
# 	GetHandleVerifier [0x007D21B8+2678216]
# 	GetHandleVerifier [0x005C17AA+512954]
# 	GetHandleVerifier [0x005C0856+509030]
# 	Ordinal0 [0x004D743B+1799227]
# 	Ordinal0 [0x004DBB68+1817448]
# 	Ordinal0 [0x004DBC55+1817685]
# 	Ordinal0 [0x004E5230+1856048]
# 	BaseThreadInitThunk [0x75AE7BA9+25]
# 	RtlInitializeExceptionChain [0x779ABB3B+107]
# 	RtlClearBits [0x779ABABF+191]

# %% [markdown]
# #sorry but i cant able to understand how to solve these problems .can u pleasae arrange me some basic class of web scraping
